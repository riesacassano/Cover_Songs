# %% [markdown]
# This notebook uses BERT to extract sentence embeddings from the memory descriptions.
#
# Following this tutorial: https://www.geeksforgeeks.org/how-to-generate-word-embedding-using-bert/

# %%
import numpy as np
import pandas as pd
import random
import torch
from transformers import BertTokenizer, BertModel
from sklearn.metrics.pairwise import cosine_similarity
import matplotlib.pyplot as plt
import scipy.stats
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.metrics import silhouette_score

# %% [markdown]
# Set random seed

# %%
random_seed = 9
random.seed(random_seed)

# set for PyTorch
torch.manual_seed(random_seed)
if torch.cuda.is_available():
    torch.cuda.manual_seed_all(random_seed)

# %% [markdown]
# Load BERT

# %%
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
model = BertModel.from_pretrained('bert-base-uncased')
# gave a JS error before, but it went away... (if happens again, ctrl+refresh button)
# https://stackoverflow.com/questions/73715821/jupyter-lab-issue-displaying-widgets-javascript-error

# %% [markdown]
# # Sentence embeddings for all memories

# %% [markdown]
# First, we generate sentence embeddings for all memories reported. While this is not used specifically in the content analysis (comparing across pairs of memories), it could be useful in future exploratory analysis.
#
# **Note:** we don't filter out "private" memories!

# %% [markdown]
# ### Load the data

# %%
all_memories = pd.read_csv('../../processed/dense/memory/all_memories.csv', header = 0)

# %%
all_memories
# Out:
#       internal_id  session song_id orig_or_cover  age_at_event  \
# 0               1        1  2013_1         cover          20.0
# 1               1        1  2016_5          orig           9.0
# 2               1        1  2017_2          orig          21.0
# 3               1        1  2017_3          orig          10.0
# 4               1        1  2018_5         cover           9.0
# ...           ...      ...     ...           ...           ...
# 2083           90        2  2011_1         cover          13.0
# 2084           90        2  2013_2          orig          16.0
# 2085           90        2  2014_1          orig          17.0
# 2086           90        2  2014_5         cover          17.0
# 2087           90        2  2015_3         cover          18.0
#
#                                             association  \
# 0                                 I do not associate it
# 1                                 I do not associate it
# 2     I do not associate with anything in particular...
# 3                                 I do not associate it
# 4                   I do not associate it with anything
# ...                                                 ...
# 2083                                      middle school
# 2084                                        high school
# 2085                                                NaN
# 2086                         latter half of high school
# 2087                                                NaN
#
#                      control  \
# 0     completely spontaneous
# 1     completely spontaneous
# 2     completely spontaneous
# 3     completely spontaneous
# 4     completely spontaneous
# ...                      ...
# 2083    somewhat spontaneous
# 2084  completely spontaneous
# 2085    somewhat spontaneous
# 2086  completely spontaneous
# 2087    somewhat spontaneous
#
#                                             description       emot_content  \
# 0     I was walking alone to one of my first few job...            neutral
# 1     I remembered when my mother threw out my Yugio...  somewhat negative
# 2     I was sitting at home alone watching a youtube...  somewhat positive
# 3     I remembered when I was at a pool party with m...            neutral
# 4     I was at a fireworks festival when I smelled s...      very negative
# ...                                                 ...                ...
# 2083  I watched a girl sing this flawlessly while we...  somewhat positive
# 2084  This was part of my "feminist awakening" on Tu...  somewhat negative
# 2085  I was alone in my childhood bedroom watching t...            neutral
# 2086  I remember sitting in my current events class ...            neutral
# 2087  I remember Taeyeon was supposed to perform thi...  somewhat negative
#
#      emot_intensity   energetic  \
# 0        not at all  not at all
# 1        not at all  not at all
# 2        not at all    a little
# 3        not at all  not at all
# 4        not at all  not at all
# ...             ...         ...
# 2083       a little    a little
# 2084       somewhat    somewhat
# 2085     not at all    a little
# 2086     not at all  not at all
# 2087       a little    a little
#
#                                              experience familiarity  \
# 0                                 I have never heard it  not at all
# 1                                 I have never heard it  not at all
# 2     I have heard it a few times over the internet ...    a little
# 3                                 I have never heard it  not at all
# 4                          I have never heard it before  not at all
# ...                                                 ...         ...
# 2083  First Adele song I heard. I like this one ok b...        very
# 2084  I always secretly liked the sound of this song...        very
# 2085                                   I don't like it!        very
# 2086  I heard it quite a bit especially back then bu...    somewhat
# 2087  Hear this on the radio all the time but never ...        very
#
#        important  preference      social     unique       vivid
# 0     not at all  not at all  not at all       very  not at all
# 1       a little  not at all   extremely  extremely  not at all
# 2     not at all  not at all    a little       very  not at all
# 3     not at all  not at all   extremely  extremely  not at all
# 4     not at all  not at all    a little  extremely  not at all
# ...          ...         ...         ...        ...         ...
# 2083    a little    a little    somewhat   a little    somewhat
# 2084    a little    a little    a little   a little        very
# 2085  not at all  not at all  not at all   a little    somewhat
# 2086  not at all  not at all    somewhat   somewhat    somewhat
# 2087  not at all  not at all    a little   a little    a little
#
# [2088 rows x 18 columns]

# %% [markdown]
# Only keep the identifying columns and the memory description.

# %%
all_memories = all_memories[['internal_id', 'song_id', 'orig_or_cover', 'description']]

# %%
all_memories
# Out:
#       internal_id song_id orig_or_cover  \
# 0               1  2013_1         cover
# 1               1  2016_5          orig
# 2               1  2017_2          orig
# 3               1  2017_3          orig
# 4               1  2018_5         cover
# ...           ...     ...           ...
# 2083           90  2011_1         cover
# 2084           90  2013_2          orig
# 2085           90  2014_1          orig
# 2086           90  2014_5         cover
# 2087           90  2015_3         cover
#
#                                             description
# 0     I was walking alone to one of my first few job...
# 1     I remembered when my mother threw out my Yugio...
# 2     I was sitting at home alone watching a youtube...
# 3     I remembered when I was at a pool party with m...
# 4     I was at a fireworks festival when I smelled s...
# ...                                                 ...
# 2083  I watched a girl sing this flawlessly while we...
# 2084  This was part of my "feminist awakening" on Tu...
# 2085  I was alone in my childhood bedroom watching t...
# 2086  I remember sitting in my current events class ...
# 2087  I remember Taeyeon was supposed to perform thi...
#
# [2088 rows x 4 columns]

# %% [markdown]
# ### Generate sentence embeddings

# %%
sentence_embeddings = []

for row in range(#len(all_memories)):
    # print every fifty rows to keep track of where we are
    if row % 50 == 0: print(row)
    
    # grab this row - keep names consistent with dataframe
    internal_id = all_memories.iloc[row]["internal_id"]
    song_id = all_memories.iloc[row]["song_id"]
    orig_or_cover = all_memories.iloc[row]["orig_or_cover"]
    description = all_memories.iloc[row]["description"]

    # tokenize the input text for the memory description
    encoding = tokenizer.batch_encode_plus([description], padding=True, truncation=True, return_tensors='pt', add_special_tokens=True)
    input_ids = encoding['input_ids']
    attention_mask = encoding['attention_mask']
    
    # generate embeddings
    with torch.no_grad():
        outputs = model(input_ids, attention_mask=attention_mask)
        sentence_embedding = outputs.pooler_output
        #average_word_embedding = outputs.last_hidden_state.mean(dim=1) # if we want to compare average word embeddings to pooled output

    # append the embeddings to our list
    sentence_embeddings.append([internal_id, song_id, orig_or_cover] + sentence_embedding.tolist()[0])

# turn list of embeddings into a dataframe
embeddings_df = pd.DataFrame(sentence_embeddings, columns = ['internal_id', 'song_id', 'orig_or_cover'] + np.arange(1,769).tolist())
embeddings_df
# Out:
# 0
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# 1550
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
#       internal_id song_id orig_or_cover         1         2         3  \
# 0               1  2013_1         cover -0.925039 -0.476511 -0.820146
# 1               1  2016_5          orig -0.725542 -0.170654 -0.016003
# 2               1  2017_2          orig -0.822758 -0.352374 -0.358245
# 3               1  2017_3          orig -0.689323 -0.106435  0.154920
# 4               1  2018_5         cover -0.834857 -0.417065 -0.782101
# ...           ...     ...           ...       ...       ...       ...
# 2083           90  2011_1         cover -0.806903 -0.383219 -0.701549
# 2084           90  2013_2          orig -0.749622 -0.499494 -0.897951
# 2085           90  2014_1          orig -0.946511 -0.576533 -0.970251
# 2086           90  2014_5         cover -0.471628 -0.115952 -0.225138
# 2087           90  2015_3         cover -0.721983 -0.425570 -0.909833
#
#              4         5         6         7  ...       759       760  \
# 0     0.806121  0.750252 -0.263882  0.900542  ...  0.415158  0.133134
# 1     0.391178  0.064678 -0.125905  0.626576  ...  0.360012  0.354670
# 2     0.545977  0.640670 -0.177868  0.559740  ...  0.360978  0.118866
# 3     0.106485  0.154481 -0.173088  0.394321  ...  0.224393  0.588233
# 4     0.466850  0.813551 -0.326551  0.459257  ...  0.394750  0.041945
# ...        ...       ...       ...       ...  ...       ...       ...
# 2083  0.506742  0.800984 -0.239791  0.634900  ...  0.222808 -0.051539
# 2084  0.491014  0.779210 -0.302061  0.551081  ...  0.448018  0.133541
# 2085  0.879920  0.885311 -0.392012  0.895518  ...  0.508017 -0.781010
# 2086 -0.160180  0.543597 -0.240385 -0.468006  ... -0.035180  0.419475
# 2087  0.541115  0.770910 -0.310529  0.531561  ...  0.349430  0.311736
#
#            761       762       763       764       765       766       767  \
# 0     0.985191  0.896381 -0.238206  0.392944  0.534719 -0.758175 -0.565566
# 1     0.153214  0.760723  0.278341  0.566524  0.412910 -0.148993 -0.570092
# 2     0.901249  0.838365  0.052868  0.700132  0.486593 -0.466681 -0.606861
# 3     0.244819  0.667610  0.404708  0.709202  0.253536 -0.193580 -0.557565
# 4     0.974859  0.705473 -0.337239  0.462324  0.496768 -0.774906 -0.668279
# ...        ...       ...       ...       ...       ...       ...       ...
# 2083  0.961630  0.716346 -0.202372  0.509185  0.361068 -0.814546 -0.614946
# 2084  0.963856  0.735331 -0.022848 -0.119280  0.569422 -0.767897 -0.654401
# 2085  0.998417  0.898583  0.064658  0.218098  0.635531 -0.880555 -0.729259
# 2086  0.791787  0.360677  0.095291  0.731498  0.116594 -0.552660 -0.409857
# 2087  0.936908  0.708413 -0.073636  0.141786  0.487754 -0.845056 -0.671185
#
#            768
# 0     0.959932
# 1     0.839836
# 2     0.880014
# 3     0.820684
# 4     0.907586
# ...        ...
# 2083  0.842037
# 2084  0.815262
# 2085  0.932932
# 2086  0.712509
# 2087  0.808039
#
# [2088 rows x 771 columns]

# %% [markdown]
# (Fifty rows takes about 2 seconds)
#
# Save the output.

# %%
embeddings_df.to_csv('../../processed/dense/memory/all_memory_embeddings.csv', index = False)

# %% [markdown]
# # Semantic distance for memory pairs

# %% [markdown]
# Now that we have all of the sentence embeddings, we compute semantic distance between pairs of memories using cosine similarity.
#
# First, identify the pairs.

# %%
embedding_distances = []

for sub in pd.unique(embeddings_df['internal_id']):
#for sub in [1,2]:
    # get just this participant's memories
    this_sub = embeddings_df[embeddings_df['internal_id'] == sub]

    # get the songs and their counts 
    these_songs, these_song_counts = np.unique(this_sub['song_id'], return_counts=True)

    # if the song shows up twice, then that's a memory pair
    for i in range(len(these_songs)):
        if these_song_counts[i] == 2: 
            song_id = these_songs[i]
            this_song = this_sub[this_sub['song_id'] == song_id]
            orig_embedding = this_song[this_song['orig_or_cover'] == 'orig'].to_numpy()[0,3:]
            cover_embedding = this_song[this_song['orig_or_cover'] == 'cover'].to_numpy()[0,3:]
            # compute semantic distance using Euclidean distance
            semantic_distance = np.linalg.norm(orig_embedding - cover_embedding)

            embedding_distances.append([sub, song_id, semantic_distance])
            
embedding_dist_df = pd.DataFrame(embedding_distances, columns = ['internal_id', 'song_id', 'semantic_distance'])
embedding_dist_df
# Out:
#      internal_id song_id  semantic_distance
# 0              1  2017_2           4.476163
# 1              2  2008_2           3.320117
# 2              2  2010_1           2.279668
# 3              2  2011_3           2.294284
# 4              2  2012_4           4.059248
# ..           ...     ...                ...
# 625           89  2011_2           5.434355
# 626           89  2012_3           4.745692
# 627           89  2015_4           3.691397
# 628           90  2011_1           3.891313
# 629           90  2015_3           2.806439
#
# [630 rows x 3 columns]

# %%
print(np.max(embedding_dist_df['semantic_distance']))
# Out:
# 18.58325032095421

# %%
embedding_dist_df.to_csv('../../processed/dense/memory/memory_pairs_semantic_distances.csv', index = False)
